# %%
import pandas as pd
import numpy as np

# %%
# loading iris dataset from sklearn
from sklearn.datasets import load_iris
iris = load_iris()
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
#     ============== ==== ==== ======= ===== ====================
#
#     :Missing Attribute Values: None
#     :Class Distribution: 33.3% for each of 3 classes.
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. topic:: References
#
#    - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#      Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#      Mathematical Statistics" (John Wiley, NY, 1950).
#    - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#      (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#    - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#      Structure and Classification Rule for Recognition in Partially Exposed
#      Environments".  IEEE Transactions on Pattern Analysis and Machine
#      Intelligence, Vol. PAMI-2, No. 1, 67-71.
#    - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#      on Information Theory, May 1972, 431-433.
#    - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#      conceptual clustering system finds 3 classes in the data.
#    - Many, many more ...

# %%
X = iris.data
y = iris.target

# %%
X[0:3], y[0:3]
# Out:
# (array([[5.1, 3.5, 1.4, 0.2],
#         [4.9, 3. , 1.4, 0.2],
#         [4.7, 3.2, 1.3, 0.2]]),
#  array([0, 0, 0]))

# %%
# one hot encoding with keras
from keras.utils import to_categorical
y = to_categorical(y)
y.shape
# Out:
# (150, 3)

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=42)

# %%
# scaling the features into [0,1] interval with MinMaxScaler
# fitting the model with only train data and transforming both train and test data with training parameters
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
scaled_X_train = scaler.transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
# creating an ANN model with 2 hidden layers
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(8, input_dim=4, activation='relu')) # layer 1
model.add(Dense(8, input_dim=4, activation='relu')) # layer 2
model.add(Dense(3, activation='softmax')) # output layer
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 8)                 40
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 27
# =================================================================
# Total params: 139
# Trainable params: 139
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fitting the model
model.fit(scaled_X_train, y_train, epochs=150, verbose=2) # verbose: level of the reporting detail
# Out:
# Epoch 1/150
# 4/4 - 0s - loss: 0.4555 - accuracy: 0.9000
# Epoch 2/150
# 4/4 - 0s - loss: 0.4542 - accuracy: 0.9100
# Epoch 3/150
# 4/4 - 0s - loss: 0.4529 - accuracy: 0.9200
# Epoch 4/150
# 4/4 - 0s - loss: 0.4523 - accuracy: 0.9200
# Epoch 5/150
# 4/4 - 0s - loss: 0.4512 - accuracy: 0.9200
# Epoch 6/150
# 4/4 - 0s - loss: 0.4496 - accuracy: 0.9200
# Epoch 7/150
# 4/4 - 0s - loss: 0.4481 - accuracy: 0.9200
# Epoch 8/150
# 4/4 - 0s - loss: 0.4470 - accuracy: 0.9100
# Epoch 9/150
# 4/4 - 0s - loss: 0.4455 - accuracy: 0.9100
# Epoch 10/150
# 4/4 - 0s - loss: 0.4441 - accuracy: 0.9100
# Epoch 11/150
# 4/4 - 0s - loss: 0.4431 - accuracy: 0.9100
# Epoch 12/150
# 4/4 - 0s - loss: 0.4419 - accuracy: 0.9200
# Epoch 13/150
# 4/4 - 0s - loss: 0.4407 - accuracy: 0.9200
# Epoch 14/150
# 4/4 - 0s - loss: 0.4390 - accuracy: 0.9100
# Epoch 15/150
# 4/4 - 0s - loss: 0.4379 - accuracy: 0.9100
# Epoch 16/150
# 4/4 - 0s - loss: 0.4368 - accuracy: 0.9100
# Epoch 17/150
# 4/4 - 0s - loss: 0.4358 - accuracy: 0.9100
# Epoch 18/150
# 4/4 - 0s - loss: 0.4348 - accuracy: 0.9100
# Epoch 19/150
# 4/4 - 0s - loss: 0.4336 - accuracy: 0.9100
# Epoch 20/150
# 4/4 - 0s - loss: 0.4327 - accuracy: 0.9100
# Epoch 21/150
# 4/4 - 0s - loss: 0.4307 - accuracy: 0.9100
# Epoch 22/150
# 4/4 - 0s - loss: 0.4294 - accuracy: 0.9100
# Epoch 23/150
# 4/4 - 0s - loss: 0.4281 - accuracy: 0.9100
# Epoch 24/150
# 4/4 - 0s - loss: 0.4273 - accuracy: 0.9200
# Epoch 25/150
# 4/4 - 0s - loss: 0.4259 - accuracy: 0.9300
# Epoch 26/150
# 4/4 - 0s - loss: 0.4246 - accuracy: 0.9300
# Epoch 27/150
# 4/4 - 0s - loss: 0.4234 - accuracy: 0.9100
# Epoch 28/150
# 4/4 - 0s - loss: 0.4223 - accuracy: 0.9200
# Epoch 29/150
# 4/4 - 0s - loss: 0.4209 - accuracy: 0.9300
# Epoch 30/150
# 4/4 - 0s - loss: 0.4206 - accuracy: 0.9300
# Epoch 31/150
# 4/4 - 0s - loss: 0.4197 - accuracy: 0.9300
# Epoch 32/150
# 4/4 - 0s - loss: 0.4180 - accuracy: 0.9300
# Epoch 33/150
# 4/4 - 0s - loss: 0.4165 - accuracy: 0.9300
# Epoch 34/150
# 4/4 - 0s - loss: 0.4150 - accuracy: 0.9300
# Epoch 35/150
# 4/4 - 0s - loss: 0.4138 - accuracy: 0.9300
# Epoch 36/150
# 4/4 - 0s - loss: 0.4130 - accuracy: 0.9300
# Epoch 37/150
# 4/4 - 0s - loss: 0.4115 - accuracy: 0.9200
# Epoch 38/150
# 4/4 - 0s - loss: 0.4105 - accuracy: 0.9100
# Epoch 39/150
# 4/4 - 0s - loss: 0.4092 - accuracy: 0.9100
# Epoch 40/150
# 4/4 - 0s - loss: 0.4080 - accuracy: 0.9100
# Epoch 41/150
# 4/4 - 0s - loss: 0.4068 - accuracy: 0.9100
# Epoch 42/150
# 4/4 - 0s - loss: 0.4057 - accuracy: 0.9200
# Epoch 43/150
# 4/4 - 0s - loss: 0.4042 - accuracy: 0.9200
# Epoch 44/150
# 4/4 - 0s - loss: 0.4031 - accuracy: 0.9300
# Epoch 45/150
# 4/4 - 0s - loss: 0.4017 - accuracy: 0.9300
# Epoch 46/150
# 4/4 - 0s - loss: 0.4009 - accuracy: 0.9100
# Epoch 47/150
# 4/4 - 0s - loss: 0.4001 - accuracy: 0.9100
# Epoch 48/150
# 4/4 - 0s - loss: 0.4000 - accuracy: 0.9100
# Epoch 49/150
# 4/4 - 0s - loss: 0.3996 - accuracy: 0.9100
# Epoch 50/150
# 4/4 - 0s - loss: 0.3981 - accuracy: 0.9100
# Epoch 51/150
# 4/4 - 0s - loss: 0.3957 - accuracy: 0.9100
# Epoch 52/150
# 4/4 - 0s - loss: 0.3935 - accuracy: 0.9300
# Epoch 53/150
# 4/4 - 0s - loss: 0.3929 - accuracy: 0.9300
# Epoch 54/150
# 4/4 - 0s - loss: 0.3920 - accuracy: 0.9400
# Epoch 55/150
# 4/4 - 0s - loss: 0.3910 - accuracy: 0.9400
# Epoch 56/150
# 4/4 - 0s - loss: 0.3895 - accuracy: 0.9400
# Epoch 57/150
# 4/4 - 0s - loss: 0.3878 - accuracy: 0.9300
# Epoch 58/150
# 4/4 - 0s - loss: 0.3866 - accuracy: 0.9300
# Epoch 59/150
# 4/4 - 0s - loss: 0.3853 - accuracy: 0.9400
# Epoch 60/150
# 4/4 - 0s - loss: 0.3845 - accuracy: 0.9400
# Epoch 61/150
# 4/4 - 0s - loss: 0.3836 - accuracy: 0.9400
# Epoch 62/150
# 4/4 - 0s - loss: 0.3822 - accuracy: 0.9400
# Epoch 63/150
# 4/4 - 0s - loss: 0.3818 - accuracy: 0.9500
# Epoch 64/150
# 4/4 - 0s - loss: 0.3806 - accuracy: 0.9400
# Epoch 65/150
# 4/4 - 0s - loss: 0.3797 - accuracy: 0.9500
# Epoch 66/150
# 4/4 - 0s - loss: 0.3785 - accuracy: 0.9600
# Epoch 67/150
# 4/4 - 0s - loss: 0.3773 - accuracy: 0.9500
# Epoch 68/150
# 4/4 - 0s - loss: 0.3759 - accuracy: 0.9500
# Epoch 69/150
# 4/4 - 0s - loss: 0.3744 - accuracy: 0.9500
# Epoch 70/150
# 4/4 - 0s - loss: 0.3733 - accuracy: 0.9400
# Epoch 71/150
# 4/4 - 0s - loss: 0.3717 - accuracy: 0.9300
# Epoch 72/150
# 4/4 - 0s - loss: 0.3705 - accuracy: 0.9300
# Epoch 73/150
# 4/4 - 0s - loss: 0.3693 - accuracy: 0.9300
# Epoch 74/150
# 4/4 - 0s - loss: 0.3683 - accuracy: 0.9400
# Epoch 75/150
# 4/4 - 0s - loss: 0.3671 - accuracy: 0.9400
# Epoch 76/150
# 4/4 - 0s - loss: 0.3660 - accuracy: 0.9300
# Epoch 77/150
# 4/4 - 0s - loss: 0.3651 - accuracy: 0.9300
# Epoch 78/150
# 4/4 - 0s - loss: 0.3641 - accuracy: 0.9200
# Epoch 79/150
# 4/4 - 0s - loss: 0.3630 - accuracy: 0.9300
# Epoch 80/150
# 4/4 - 0s - loss: 0.3619 - accuracy: 0.9300
# Epoch 81/150
# 4/4 - 0s - loss: 0.3609 - accuracy: 0.9300
# Epoch 82/150
# 4/4 - 0s - loss: 0.3605 - accuracy: 0.9200
# Epoch 83/150
# 4/4 - 0s - loss: 0.3590 - accuracy: 0.9200
# Epoch 84/150
# 4/4 - 0s - loss: 0.3577 - accuracy: 0.9200
# Epoch 85/150
# 4/4 - 0s - loss: 0.3567 - accuracy: 0.9300
# Epoch 86/150
# 4/4 - 0s - loss: 0.3553 - accuracy: 0.9300
# Epoch 87/150
# 4/4 - 0s - loss: 0.3543 - accuracy: 0.9300
# Epoch 88/150
# 4/4 - 0s - loss: 0.3529 - accuracy: 0.9400
# Epoch 89/150
# 4/4 - 0s - loss: 0.3516 - accuracy: 0.9400
# Epoch 90/150
# 4/4 - 0s - loss: 0.3516 - accuracy: 0.9600
# Epoch 91/150
# 4/4 - 0s - loss: 0.3510 - accuracy: 0.9600
# Epoch 92/150
# 4/4 - 0s - loss: 0.3497 - accuracy: 0.9600
# Epoch 93/150
# 4/4 - 0s - loss: 0.3487 - accuracy: 0.9600
# Epoch 94/150
# 4/4 - 0s - loss: 0.3465 - accuracy: 0.9400
# Epoch 95/150
# 4/4 - 0s - loss: 0.3452 - accuracy: 0.9300
# Epoch 96/150
# 4/4 - 0s - loss: 0.3440 - accuracy: 0.9200
# Epoch 97/150
# 4/4 - 0s - loss: 0.3420 - accuracy: 0.9200
# Epoch 98/150
# 4/4 - 0s - loss: 0.3390 - accuracy: 0.9200
# Epoch 99/150
# 4/4 - 0s - loss: 0.3350 - accuracy: 0.9300
# Epoch 100/150
# 4/4 - 0s - loss: 0.3318 - accuracy: 0.9600
# Epoch 101/150
# 4/4 - 0s - loss: 0.3286 - accuracy: 0.9600
# Epoch 102/150
# 4/4 - 0s - loss: 0.3264 - accuracy: 0.9600
# Epoch 103/150
# 4/4 - 0s - loss: 0.3231 - accuracy: 0.9600
# Epoch 104/150
# 4/4 - 0s - loss: 0.3190 - accuracy: 0.9600
# Epoch 105/150
# 4/4 - 0s - loss: 0.3144 - accuracy: 0.9600
# Epoch 106/150
# 4/4 - 0s - loss: 0.3097 - accuracy: 0.9600
# Epoch 107/150
# 4/4 - 0s - loss: 0.3056 - accuracy: 0.9600
# Epoch 108/150
# 4/4 - 0s - loss: 0.3016 - accuracy: 0.9400
# Epoch 109/150
# 4/4 - 0s - loss: 0.2978 - accuracy: 0.9400
# Epoch 110/150
# 4/4 - 0s - loss: 0.2943 - accuracy: 0.9300
# Epoch 111/150
# 4/4 - 0s - loss: 0.2902 - accuracy: 0.9300
# Epoch 112/150
# 4/4 - 0s - loss: 0.2867 - accuracy: 0.9400
# Epoch 113/150
# 4/4 - 0s - loss: 0.2823 - accuracy: 0.9600
# Epoch 114/150
# 4/4 - 0s - loss: 0.2791 - accuracy: 0.9600
# Epoch 115/150
# 4/4 - 0s - loss: 0.2754 - accuracy: 0.9600
# Epoch 116/150
# 4/4 - 0s - loss: 0.2743 - accuracy: 0.9600
# Epoch 117/150
# 4/4 - 0s - loss: 0.2727 - accuracy: 0.9400
# Epoch 118/150
# 4/4 - 0s - loss: 0.2705 - accuracy: 0.9400
# Epoch 119/150
# 4/4 - 0s - loss: 0.2673 - accuracy: 0.9600
# Epoch 120/150
# 4/4 - 0s - loss: 0.2640 - accuracy: 0.9600
# Epoch 121/150
# 4/4 - 0s - loss: 0.2607 - accuracy: 0.9600
# Epoch 122/150
# 4/4 - 0s - loss: 0.2578 - accuracy: 0.9600
# Epoch 123/150
# 4/4 - 0s - loss: 0.2555 - accuracy: 0.9600
# Epoch 124/150
# 4/4 - 0s - loss: 0.2542 - accuracy: 0.9600
# Epoch 125/150
# 4/4 - 0s - loss: 0.2523 - accuracy: 0.9400
# Epoch 126/150
# 4/4 - 0s - loss: 0.2503 - accuracy: 0.9400
# Epoch 127/150
# 4/4 - 0s - loss: 0.2480 - accuracy: 0.9500
# Epoch 128/150
# 4/4 - 0s - loss: 0.2460 - accuracy: 0.9600
# Epoch 129/150
# 4/4 - 0s - loss: 0.2444 - accuracy: 0.9600
# Epoch 130/150
# 4/4 - 0s - loss: 0.2424 - accuracy: 0.9600
# Epoch 131/150
# 4/4 - 0s - loss: 0.2411 - accuracy: 0.9600
# Epoch 132/150
# 4/4 - 0s - loss: 0.2389 - accuracy: 0.9600
# Epoch 133/150
# 4/4 - 0s - loss: 0.2377 - accuracy: 0.9600
# Epoch 134/150
# 4/4 - 0s - loss: 0.2365 - accuracy: 0.9600
# Epoch 135/150
# 4/4 - 0s - loss: 0.2349 - accuracy: 0.9600
# Epoch 136/150
# 4/4 - 0s - loss: 0.2333 - accuracy: 0.9600
# Epoch 137/150
# 4/4 - 0s - loss: 0.2321 - accuracy: 0.9600
# Epoch 138/150
# 4/4 - 0s - loss: 0.2308 - accuracy: 0.9600
# Epoch 139/150
# 4/4 - 0s - loss: 0.2294 - accuracy: 0.9600
# Epoch 140/150
# 4/4 - 0s - loss: 0.2283 - accuracy: 0.9600
# Epoch 141/150
# 4/4 - 0s - loss: 0.2273 - accuracy: 0.9600
# Epoch 142/150
# 4/4 - 0s - loss: 0.2265 - accuracy: 0.9600
# Epoch 143/150
# 4/4 - 0s - loss: 0.2249 - accuracy: 0.9600
# Epoch 144/150
# 4/4 - 0s - loss: 0.2231 - accuracy: 0.9600
# Epoch 145/150
# 4/4 - 0s - loss: 0.2226 - accuracy: 0.9600
# Epoch 146/150
# 4/4 - 0s - loss: 0.2214 - accuracy: 0.9600
# Epoch 147/150
# 4/4 - 0s - loss: 0.2201 - accuracy: 0.9600
# Epoch 148/150
# 4/4 - 0s - loss: 0.2190 - accuracy: 0.9600
# Epoch 149/150
# 4/4 - 0s - loss: 0.2180 - accuracy: 0.9600
# Epoch 150/150
# 4/4 - 0s - loss: 0.2171 - accuracy: 0.9600

# %%
# predicting probability outputs
model.predict(scaled_X_test)
# Out:
# array([[3.90587316e-04, 7.65075386e-01, 2.34534010e-01],
#        [9.61868286e-01, 2.40315180e-02, 1.41001977e-02],
#        [2.24887287e-09, 2.47052256e-02, 9.75294769e-01],
#        [2.01487972e-04, 6.60464346e-01, 3.39334130e-01],
#        [3.71597635e-05, 5.22306442e-01, 4.77656364e-01],
#        [9.51122046e-01, 3.13554779e-02, 1.75224952e-02],
#        [4.13243985e-03, 8.09142232e-01, 1.86725378e-01],
#        [2.17531522e-07, 9.57205370e-02, 9.04279232e-01],
#        [5.73630678e-05, 3.59913081e-01, 6.40029609e-01],
#        [2.11873883e-03, 8.17746103e-01, 1.80135205e-01],
#        [3.47388323e-06, 2.75812328e-01, 7.24184215e-01],
#        [9.68567729e-01, 1.95894279e-02, 1.18428767e-02],
#        [9.70295787e-01, 1.84344482e-02, 1.12697352e-02],
#        [9.68960166e-01, 1.93267222e-02, 1.17130913e-02],
#        [9.74155605e-01, 1.58715621e-02, 9.97270737e-03],
#        [8.06578901e-05, 6.68034375e-01, 3.31884921e-01],
#        [2.14294104e-07, 9.46244746e-02, 9.05375302e-01],
#        [3.84928216e-03, 8.09966624e-01, 1.86184078e-01],
#        [7.32084678e-04, 7.81463981e-01, 2.17803910e-01],
#        [2.85383891e-07, 8.62527713e-02, 9.13746953e-01],
#        [9.68514919e-01, 1.96247194e-02, 1.18602812e-02],
#        [2.40193167e-05, 4.18192834e-01, 5.81783056e-01],
#        [9.63134527e-01, 2.32476629e-02, 1.36178462e-02],
#        [4.86201088e-07, 1.08350515e-01, 8.91649008e-01],
#        [4.18832009e-08, 1.55158550e-01, 8.44841421e-01],
#        [2.34533971e-07, 8.87130350e-02, 9.11286652e-01],
#        [5.95521897e-07, 1.18044101e-01, 8.81955326e-01],
#        [7.23114439e-08, 7.69977942e-02, 9.23002124e-01],
#        [9.61250722e-01, 2.45247521e-02, 1.42245097e-02],
#        [9.65607822e-01, 2.15775445e-02, 1.28146913e-02],
#        [9.79356349e-01, 1.24608409e-02, 8.18285905e-03],
#        [9.77152288e-01, 1.38998199e-02, 8.94792285e-03],
#        [1.17009084e-04, 7.03075349e-01, 2.96807647e-01],
#        [9.71540272e-01, 1.76054947e-02, 1.08541818e-02],
#        [9.72888231e-01, 1.67104695e-02, 1.04013318e-02],
#        [3.45104354e-06, 1.68210030e-01, 8.31786513e-01],
#        [1.26596322e-04, 7.05938458e-01, 2.93935001e-01],
#        [9.71128166e-01, 1.78797599e-02, 1.09920725e-02],
#        [9.74848449e-01, 1.54142771e-02, 9.73727833e-03],
#        [9.82236028e-01, 1.05970968e-02, 7.16686388e-03],
#        [1.20467976e-05, 2.67373860e-01, 7.32614040e-01],
#        [2.40436028e-04, 7.55077183e-01, 2.44682342e-01],
#        [4.73904656e-05, 5.99426031e-01, 4.00526553e-01],
#        [9.72290218e-01, 1.71071105e-02, 1.06025748e-02],
#        [9.73235846e-01, 1.64800957e-02, 1.02840420e-02],
#        [8.72855075e-03, 7.97095478e-01, 1.94176018e-01],
#        [3.81361824e-05, 4.90369856e-01, 5.09591997e-01],
#        [5.25457745e-06, 3.27900499e-01, 6.72094226e-01],
#        [1.28448984e-04, 6.83480144e-01, 3.16391349e-01],
#        [1.28944002e-08, 5.72080947e-02, 9.42791939e-01]], dtype=float32)

# %%
# predicting class outputs
y_pred = np.argmax(model.predict(scaled_X_test), axis=-1)
y_pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 2, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0, 1, 2, 2, 1, 2], dtype=int64)

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
print('Accuracy score ')
print(accuracy_score(y_pred, y_test.argmax(axis=1)))
print('------ ')
print('Confusion matrix ')
print(confusion_matrix(y_pred, y_test.argmax(axis=1)))
print('------ ')
print('Classification report ')
print(classification_report(y_pred, y_test.argmax(axis=1)))
# Out:
# Accuracy score
# 0.98
# ------
# Confusion matrix
# [[19  0  0]
#  [ 0 14  0]
#  [ 0  1 16]]
# ------
# Classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.93      1.00      0.97        14
#            2       1.00      0.94      0.97        17
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50

# %%
#saving the model for later usage
model.save('myfirstmodel.h5')

# %%
# loading a model and using it as an existing one
from keras.models import load_model
loaded_model = load_model('myfirstmodel.h5')
loaded_model.predict(scaled_X_test)
# Out:
# array([[3.90587316e-04, 7.65075386e-01, 2.34534010e-01],
#        [9.61868286e-01, 2.40315180e-02, 1.41001977e-02],
#        [2.24887287e-09, 2.47052256e-02, 9.75294769e-01],
#        [2.01487972e-04, 6.60464346e-01, 3.39334130e-01],
#        [3.71597635e-05, 5.22306442e-01, 4.77656364e-01],
#        [9.51122046e-01, 3.13554779e-02, 1.75224952e-02],
#        [4.13243985e-03, 8.09142232e-01, 1.86725378e-01],
#        [2.17531522e-07, 9.57205370e-02, 9.04279232e-01],
#        [5.73630678e-05, 3.59913081e-01, 6.40029609e-01],
#        [2.11873883e-03, 8.17746103e-01, 1.80135205e-01],
#        [3.47388323e-06, 2.75812328e-01, 7.24184215e-01],
#        [9.68567729e-01, 1.95894279e-02, 1.18428767e-02],
#        [9.70295787e-01, 1.84344482e-02, 1.12697352e-02],
#        [9.68960166e-01, 1.93267222e-02, 1.17130913e-02],
#        [9.74155605e-01, 1.58715621e-02, 9.97270737e-03],
#        [8.06578901e-05, 6.68034375e-01, 3.31884921e-01],
#        [2.14294104e-07, 9.46244746e-02, 9.05375302e-01],
#        [3.84928216e-03, 8.09966624e-01, 1.86184078e-01],
#        [7.32084678e-04, 7.81463981e-01, 2.17803910e-01],
#        [2.85383891e-07, 8.62527713e-02, 9.13746953e-01],
#        [9.68514919e-01, 1.96247194e-02, 1.18602812e-02],
#        [2.40193167e-05, 4.18192834e-01, 5.81783056e-01],
#        [9.63134527e-01, 2.32476629e-02, 1.36178462e-02],
#        [4.86201088e-07, 1.08350515e-01, 8.91649008e-01],
#        [4.18832009e-08, 1.55158550e-01, 8.44841421e-01],
#        [2.34533971e-07, 8.87130350e-02, 9.11286652e-01],
#        [5.95521897e-07, 1.18044101e-01, 8.81955326e-01],
#        [7.23114439e-08, 7.69977942e-02, 9.23002124e-01],
#        [9.61250722e-01, 2.45247521e-02, 1.42245097e-02],
#        [9.65607822e-01, 2.15775445e-02, 1.28146913e-02],
#        [9.79356349e-01, 1.24608409e-02, 8.18285905e-03],
#        [9.77152288e-01, 1.38998199e-02, 8.94792285e-03],
#        [1.17009084e-04, 7.03075349e-01, 2.96807647e-01],
#        [9.71540272e-01, 1.76054947e-02, 1.08541818e-02],
#        [9.72888231e-01, 1.67104695e-02, 1.04013318e-02],
#        [3.45104354e-06, 1.68210030e-01, 8.31786513e-01],
#        [1.26596322e-04, 7.05938458e-01, 2.93935001e-01],
#        [9.71128166e-01, 1.78797599e-02, 1.09920725e-02],
#        [9.74848449e-01, 1.54142771e-02, 9.73727833e-03],
#        [9.82236028e-01, 1.05970968e-02, 7.16686388e-03],
#        [1.20467976e-05, 2.67373860e-01, 7.32614040e-01],
#        [2.40436028e-04, 7.55077183e-01, 2.44682342e-01],
#        [4.73904656e-05, 5.99426031e-01, 4.00526553e-01],
#        [9.72290218e-01, 1.71071105e-02, 1.06025748e-02],
#        [9.73235846e-01, 1.64800957e-02, 1.02840420e-02],
#        [8.72855075e-03, 7.97095478e-01, 1.94176018e-01],
#        [3.81361824e-05, 4.90369856e-01, 5.09591997e-01],
#        [5.25457745e-06, 3.27900499e-01, 6.72094226e-01],
#        [1.28448984e-04, 6.83480144e-01, 3.16391349e-01],
#        [1.28944002e-08, 5.72080947e-02, 9.42791939e-01]], dtype=float32)
